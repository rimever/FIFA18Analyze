# %%
import pandas as pd

data = pd.read_csv('CompleteDataset.csv',index_col=0)
# Out:
# /Users/rim/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                 Name  Age                                            Photo  \
# 0  Cristiano Ronaldo   32   https://cdn.sofifa.org/48/18/players/20801.png
# 1           L. Messi   30  https://cdn.sofifa.org/48/18/players/158023.png
# 2             Neymar   25  https://cdn.sofifa.org/48/18/players/190871.png
# 3          L. Suárez   30  https://cdn.sofifa.org/48/18/players/176580.png
# 4           M. Neuer   31  https://cdn.sofifa.org/48/18/players/167495.png
#
#   Nationality                                 Flag  Overall  Potential  \
# 0    Portugal  https://cdn.sofifa.org/flags/38.png       94         94
# 1   Argentina  https://cdn.sofifa.org/flags/52.png       93         93
# 2      Brazil  https://cdn.sofifa.org/flags/54.png       92         94
# 3     Uruguay  https://cdn.sofifa.org/flags/60.png       92         92
# 4     Germany  https://cdn.sofifa.org/flags/21.png       92         92
#
#                   Club                                   Club Logo   Value  \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  €95.5M
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png   €105M
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png   €123M
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png    €97M
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png    €61M
#
#    ...     RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  ...   61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  ...   57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  ...   59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  ...   64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 74 columns]

# %%
data.describe()
# Out:
#                 Age       Overall     Potential       Special           CAM  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  15952.000000
# mean      25.144541     66.247984     71.190813   1594.095100     59.251755
# std        4.614272      6.987965      6.102199    272.151435      9.880164
# min       16.000000     46.000000     46.000000    728.000000     27.000000
# 25%       21.000000     62.000000     67.000000   1449.000000     53.000000
# 50%       25.000000     66.000000     71.000000   1633.000000     60.000000
# 75%       28.000000     71.000000     75.000000   1786.000000     66.000000
# max       47.000000     94.000000     94.000000   2291.000000     92.000000
#
#                  CB           CDM            CF            CM             ID  \
# count  15952.000000  15952.000000  15952.000000  15952.000000   17981.000000
# mean      55.550464     56.865283     59.030028     58.506833  207658.710138
# std       12.192579     10.310178      9.926988      8.888040   32291.667313
# min       25.000000     26.000000     27.000000     30.000000      16.000000
# 25%       45.000000     49.000000     53.000000     53.000000  192622.000000
# 50%       57.000000     58.000000     60.000000     59.000000  214057.000000
# 75%       65.000000     65.000000     66.000000     65.000000  231448.000000
# max       87.000000     85.000000     92.000000     87.000000  241219.000000
#
#            ...                 RB           RCB           RCM           RDM  \
# count      ...       15952.000000  15952.000000  15952.000000  15952.000000
# mean       ...          56.979689     55.550464     58.506833     56.865283
# std        ...           9.791627     12.192579      8.888040     10.310178
# min        ...          30.000000     25.000000     30.000000     26.000000
# 25%        ...          50.000000     45.000000     53.000000     49.000000
# 50%        ...          58.000000     57.000000     59.000000     58.000000
# 75%        ...          64.000000     65.000000     65.000000     65.000000
# max        ...          84.000000     87.000000     87.000000     85.000000
#
#                  RF            RM            RS            RW           RWB  \
# count  15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# mean      59.030028     60.057736     58.204050     59.359265     57.698721
# std        9.926988      9.349180      9.181392      9.978084      9.142825
# min       27.000000     28.000000     31.000000     26.000000     31.000000
# 25%       53.000000     54.000000     52.000000     53.000000     51.000000
# 50%       60.000000     61.000000     59.000000     60.000000     58.000000
# 75%       66.000000     67.000000     65.000000     66.000000     64.000000
# max       92.000000     90.000000     92.000000     91.000000     84.000000
#
#                  ST
# count  15952.000000
# mean      58.204050
# std        9.181392
# min       31.000000
# 25%       52.000000
# 50%       59.000000
# 75%       65.000000
# max       92.000000
#
# [8 rows x 31 columns]

# %%
high_age = data[data.Age == 47]
high_age.head()
# Out:
#                 Name  Age                                           Photo  \
# 17977  B. Richardson   47  https://cdn.sofifa.org/48/18/players/11728.png
#
#       Nationality                                 Flag  Overall  Potential  \
# 17977     England  https://cdn.sofifa.org/flags/14.png       46         46
#
#                     Club                                    Club Logo Value  \
# 17977  Wycombe Wanderers  https://cdn.sofifa.org/24/18/teams/1933.png    €0
#
#       ...  RB  RCB RCM RDM  RF  RM  RS  RW RWB  ST
# 17977 ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [1 rows x 74 columns]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

overall_data = data['Overall']
age_data = data['Age']

plt.scatter(age_data,overall_data)

# %%
veteran_data = data[(data.Age > 33) & (data.Overall > 80)]
veteran_data.head()
# Out:
#               Name  Age                                            Photo  \
# 18       G. Buffon   39    https://cdn.sofifa.org/48/18/players/1179.png
# 31  Z. Ibrahimović   35   https://cdn.sofifa.org/48/18/players/41236.png
# 66       F. Ribéry   34  https://cdn.sofifa.org/48/18/players/156616.png
# 67            Pepe   34  https://cdn.sofifa.org/48/18/players/120533.png
# 68         P. Čech   35   https://cdn.sofifa.org/48/18/players/48940.png
#
#        Nationality                                 Flag  Overall  Potential  \
# 18           Italy  https://cdn.sofifa.org/flags/27.png       89         89
# 31          Sweden  https://cdn.sofifa.org/flags/46.png       88         88
# 66          France  https://cdn.sofifa.org/flags/18.png       86         86
# 67        Portugal  https://cdn.sofifa.org/flags/38.png       86         86
# 68  Czech Republic  https://cdn.sofifa.org/flags/12.png       86         86
#
#                  Club                                   Club Logo   Value  \
# 18           Juventus   https://cdn.sofifa.org/24/18/teams/45.png   €4.5M
# 31  Manchester United   https://cdn.sofifa.org/24/18/teams/11.png    €27M
# 66   FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  €22.5M
# 67        Beşiktaş JK  https://cdn.sofifa.org/24/18/teams/327.png  €13.5M
# 68            Arsenal    https://cdn.sofifa.org/24/18/teams/1.png  €10.5M
#
#     ...     RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 18  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 31  ...   54.0  52.0  78.0  60.0  83.0  80.0  84.0  82.0  58.0  84.0
# 66  ...   55.0  42.0  78.0  57.0  83.0  83.0  77.0  84.0  61.0  77.0
# 67  ...   75.0  83.0  63.0  76.0  59.0  59.0  61.0  58.0  72.0  61.0
# 68  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 74 columns]

# %%
temp_data = data.Value.replace(r'[€KM]', '', regex=True).astype(float) * data.Value.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(1).replace(['K','M'], [10**3, 10**6])
print(temp_data)
data.Value = temp_data
# Out:
# 0         95500000.0
# 1        105000000.0
# 2        123000000.0
# 3         97000000.0
# 4         61000000.0
# 5         92000000.0
# 6         64500000.0
# 7         90500000.0
# 8         79000000.0
# 9         77000000.0
# 10        52000000.0
# 11        83000000.0
# 12        59000000.0
# 13        67500000.0
# 14        57000000.0
# 15        69500000.0
# 16        66500000.0
# 17        38000000.0
# 18         4500000.0
# 19        79000000.0
# 20        57000000.0
# 21        75000000.0
# 22        70500000.0
# 23        61000000.0
# 24        44000000.0
# 25        48000000.0
# 26        40000000.0
# 27        48000000.0
# 28        60000000.0
# 29        38000000.0
#             ...
# 17951        40000.0
# 17952        60000.0
# 17953        60000.0
# 17954        60000.0
# 17955        60000.0
# 17956        50000.0
# 17957        50000.0
# 17958        40000.0
# 17959        60000.0
# 17960        70000.0
# 17961        60000.0
# 17962        50000.0
# 17963        50000.0
# 17964        60000.0
# 17965        60000.0
# 17966        60000.0
# 17967        60000.0
# 17968        60000.0
# 17969        60000.0
# 17970        40000.0
# 17971        60000.0
# 17972        60000.0
# 17973        50000.0
# 17974        40000.0
# 17975        30000.0
# 17976        50000.0
# 17977            0.0
# 17978        60000.0
# 17979        60000.0
# 17980        50000.0
# Name: Value, Length: 17981, dtype: float64

# %%
overall_data = data['Overall']
value_data = data['Value']

plt.scatter(overall_data,value_data)

# %%
bargain_data = data[(data.Value < 20000000) & (data.Overall > 84)]
bargain_data.head()
# Out:
#            Name  Age                                            Photo  \
# 18    G. Buffon   39    https://cdn.sofifa.org/48/18/players/1179.png
# 67         Pepe   34  https://cdn.sofifa.org/48/18/players/120533.png
# 68      P. Čech   35   https://cdn.sofifa.org/48/18/players/48940.png
# 91  A. Barzagli   36  https://cdn.sofifa.org/48/18/players/137186.png
#
#        Nationality                                 Flag  Overall  Potential  \
# 18           Italy  https://cdn.sofifa.org/flags/27.png       89         89
# 67        Portugal  https://cdn.sofifa.org/flags/38.png       86         86
# 68  Czech Republic  https://cdn.sofifa.org/flags/12.png       86         86
# 91           Italy  https://cdn.sofifa.org/flags/27.png       85         85
#
#            Club                                   Club Logo       Value  ...   \
# 18     Juventus   https://cdn.sofifa.org/24/18/teams/45.png   4500000.0  ...
# 67  Beşiktaş JK  https://cdn.sofifa.org/24/18/teams/327.png  13500000.0  ...
# 68      Arsenal    https://cdn.sofifa.org/24/18/teams/1.png  10500000.0  ...
# 91     Juventus   https://cdn.sofifa.org/24/18/teams/45.png   5000000.0  ...
#
#       RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 18   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 67  75.0  83.0  63.0  76.0  59.0  59.0  61.0  58.0  72.0  61.0
# 68   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 91  75.0  83.0  63.0  76.0  55.0  57.0  53.0  55.0  71.0  53.0
#
# [4 rows x 74 columns]
